# %%
# 📁 Standard libraries
import os
import re
import json
import socket
import ipaddress

# 🧪 Third-party libraries
import numpy as np
from dotenv import load_dotenv 

# 🧠 AI/NLP
from openai import OpenAI
from sentence_transformers import SentenceTransformer
from langchain.text_splitter import RecursiveCharacterTextSplitter

# 🔍 Vector DB
from pinecone import Pinecone, ServerlessSpec
from tqdm import tqdm


from langchain.vectorstores import Pinecone as LangchainPinecone
from langchain.embeddings import HuggingFaceEmbeddings

from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA

from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA

from langchain_groq import ChatGroq

# %%
load_dotenv(override=True)

API_KEY = os.getenv("GROQ_API_KEY")
BASE_URL = os.getenv("GROQ_BASE_URL")

client = OpenAI(api_key=API_KEY, base_url =BASE_URL)
MODEL = "llama3-70b-8192"

if not API_KEY:
    print("No API_Key found, Please set the API_KEY.")
    exit(1)
elif API_KEY.strip() != API_KEY:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
load_dotenv(override=True)
# if not load_dotenv():
#     print("Warning: .env file not loaded. Make sure it exists.")

PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
# Replace with your real values
PINECONE_API_KEY = PINECONE_API_KEY

if not PINECONE_API_KEY:
    raise ValueError("PINECONE_API_KEY environment variable not set")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
# Directory where your scraped text files are saved
data_dir = "scraped_pages"

# This will store all your documents
documents = []

# Loop through all text files in that folder
for filename in os.listdir(data_dir):
    if filename.endswith(".txt"):
        filepath = os.path.join(data_dir, filename)
        with open(filepath, "r", encoding="utf-8") as f:
            raw_text = f.read().strip()
            
            # Split by lines
            lines = raw_text.split("\n")
            
            # Extract URL from the first line
            url = None
            if lines and lines[0].startswith("URL:"):
                url = lines[0].replace("URL:", "").strip()
                content = "\n".join(lines[1:]).strip()
            else:
                content = raw_text  # fallback if URL line not found
            
            # Save as structured dict
            documents.append({
                "filename": filename,
                "url": url,
                "content": content
            })

# %%
# documents

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)

chunks = []

for doc in documents:
    split_chunks = splitter.split_text(doc["content"])
    for chunk in split_chunks:
        chunks.append({
            "chunk": chunk,
            "source": doc["filename"],
            "url": doc["url"]
        })

# %%
len(chunks)
# Out:
# 7733

# %%
# ✅ Load the model
embedding_model = SentenceTransformer("all-mpnet-base-v2")

# ✅ Prepare text with "passage: " prefix (required by E5)
texts_to_embed = [f"passage: {chunk['chunk']}" for chunk in chunks]

# ✅ Batch encode all 7,339 chunks at once
vectors = embedding_model.encode(
    texts_to_embed,
    batch_size=64,                 # ⚡ Increase if you have more RAM/GPU
    show_progress_bar=True,
    normalize_embeddings=True      # ✅ Normalize for cosine similarity
)

# ✅ Attach embeddings to your chunks
for i, vec in enumerate(vectors):
    chunks[i]["embedding"] = vec.tolist()  # Optional: convert to list if saving to JSON
# Out:
# Batches:   0%|          | 0/121 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 8
#       5 texts_to_embed = [f"passage: {chunk['chunk']}" for chunk in chunks]
#       7 # ✅ Batch encode all 7,339 chunks at once
# ----> 8 vectors = embedding_model.encode(
#       9     texts_to_embed,
#      10     batch_size=64,                 # ⚡ Increase if you have more RAM/GPU
#      11     show_progress_bar=True,
#      12     normalize_embeddings=True      # ✅ Normalize for cosine similarity
#      13 )
#      15 # ✅ Attach embeddings to your chunks
#      16 for i, vec in enumerate(vectors):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sentence_transformers\SentenceTransformer.py:1052, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1049 features.update(extra_features)
#    1051 with torch.no_grad():
# -> 1052     out_features = self.forward(features, **kwargs)
#    1053     if self.device.type == "hpu":
#    1054         out_features = copy.deepcopy(out_features)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sentence_transformers\SentenceTransformer.py:1133, in SentenceTransformer.forward(self, input, **kwargs)
#    1127             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1128         module_kwargs = {
#    1129             key: value
#    1130             for key, value in kwargs.items()
#    1131             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1132         }
# -> 1133     input = module(input, **module_kwargs)
#    1134 return input
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sentence_transformers\models\Transformer.py:437, in Transformer.forward(self, features, **kwargs)
#     430 """Returns token_embeddings, cls_token"""
#     431 trans_features = {
#     432     key: value
#     433     for key, value in features.items()
#     434     if key in ["input_ids", "attention_mask", "token_type_ids", "inputs_embeds"]
#     435 }
# --> 437 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     438 token_embeddings = outputs[0]
#     439 features["token_embeddings"] = token_embeddings
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\models\mpnet\modeling_mpnet.py:482, in MPNetModel.forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, **kwargs)
#     480 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     481 embedding_output = self.embeddings(input_ids=input_ids, position_ids=position_ids, inputs_embeds=inputs_embeds)
# --> 482 encoder_outputs = self.encoder(
#     483     embedding_output,
#     484     attention_mask=extended_attention_mask,
#     485     head_mask=head_mask,
#     486     output_attentions=output_attentions,
#     487     output_hidden_states=output_hidden_states,
#     488     return_dict=return_dict,
#     489 )
#     490 sequence_output = encoder_outputs[0]
#     491 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\models\mpnet\modeling_mpnet.py:334, in MPNetEncoder.forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict, **kwargs)
#     331 if output_hidden_states:
#     332     all_hidden_states = all_hidden_states + (hidden_states,)
# --> 334 layer_outputs = layer_module(
#     335     hidden_states,
#     336     attention_mask,
#     337     head_mask[i],
#     338     position_bias,
#     339     output_attentions=output_attentions,
#     340     **kwargs,
#     341 )
#     342 hidden_states = layer_outputs[0]
#     344 if output_attentions:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\models\mpnet\modeling_mpnet.py:304, in MPNetLayer.forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     301 outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#     303 intermediate_output = self.intermediate(attention_output)
# --> 304 layer_output = self.output(intermediate_output, attention_output)
#     305 outputs = (layer_output,) + outputs
#     306 return outputs
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\models\mpnet\modeling_mpnet.py:271, in MPNetOutput.forward(self, hidden_states, input_tensor)
#     270 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 271     hidden_states = self.dense(hidden_states)
#     272     hidden_states = self.dropout(hidden_states)
#     273     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
# Initialize client
pc = Pinecone(api_key=PINECONE_API_KEY)

# Configuration
index_name = "chatbot-index"
dimension = 768  # for E5-base-v2
metric = "cosine"

# ✅ Check if index exists, else create it
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=dimension,
        metric=metric,
        spec=ServerlessSpec(
            cloud="aws",             # Based on Pinecone environment info
            region="us-east-1"       # your region from Pinecone Console
        )
    )

# ✅ Connect to index
index = pc.Index(index_name)

# %%
batch_size = 100  # Upsert in batches (efficient & safe)
batch = []

for i, chunk in enumerate(tqdm(chunks)):
    vector_id = f"chunk-{i}"  # Unique ID for Pinecone

    vector = {
        "id": vector_id,
        "values": chunk["embedding"],  # The 768-dimensional vector from E5
        "metadata": {
            "text": chunk["chunk"],     # Original text chunk
            "source": chunk["source"],  # File or page name
            "url": chunk["url"]         # Optional if you have it
        }
    }

    batch.append(vector)

    # ⬆️ Upload in batches
    if len(batch) == batch_size or i == len(chunks) - 1:
        index.upsert(vectors=batch)
        batch = []  # Reset for next batch
# Out:
#   9%|▉         | 699/7733 [00:09<01:30, 77.45it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 21
#      19 # ⬆️ Upload in batches
#      20 if len(batch) == batch_size or i == len(chunks) - 1:
# ---> 21     index.upsert(vectors=batch)
#      22     batch = []
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      12 @wraps(func)
#      13 def inner_func(*args, **kwargs):
#      14     try:
# ---> 15         return func(*args, **kwargs)
#      16     except Exception as e:
#      17         # Lazy import of urllib3 exceptions
#      18         from urllib3.exceptions import MaxRetryError, ProtocolError as Urllib3ProtocolError
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pinecone\db_data\index.py:212, in Index.upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     205     raise ValueError(
#     206         "async_req is not supported when batch_size is provided."
#     207         "To upsert in parallel, please follow: "
#     208         "https://docs.pinecone.io/docs/insert-data#sending-upserts-in-parallel"
#     209     )
#     211 if batch_size is None:
# --> 212     return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     214 if not isinstance(batch_size, int) or batch_size <= 0:
#     215     raise ValueError("batch_size must be a positive integer")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pinecone\db_data\index.py:238, in Index._upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     229 def _upsert_batch(
#     230     self,
#     231     vectors: Union[
#    (...)
#     236     **kwargs,
#     237 ) -> UpsertResponse:
# --> 238     return self._vector_api.upsert_vectors(
#     239         IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#     240         **self._openapi_kwargs(kwargs),
#     241     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)
#     100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:675, in VectorOperationsApi.__init__.<locals>.__upsert_vectors(self, upsert_request, **kwargs)
#     673 kwargs = self._process_openapi_kwargs(kwargs)
#     674 kwargs["upsert_request"] = upsert_request
# --> 675 return self.call_with_http_info(**kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)
#     129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)
#     302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)
#     344     ),
#     345 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     376     return self.rest_client.OPTIONS(
#     377         url,
#     378         query_params=query_params,
#    (...)
#     383         body=body,
#     384     )
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#    (...)
#     403         body=body,
#     404     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)
#     144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pinecone\openapi_support\rest_urllib3.py:190, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     188         else:  # content_type == "application/json":
#     189             request_body = json.dumps(body)
# --> 190     r = self.pool_manager.request(
#     191         method,
#     192         url,
#     193         body=request_body,
#     194         preload_content=_preload_content,
#     195         timeout=timeout,
#     196         headers=headers,
#     197     )
#     199 elif content_type == "application/x-www-form-urlencoded":  # noqa: E501
#     200     r = self.pool_manager.request(
#     201         method,
#     202         url,
#    (...)
#     207         headers=headers,
#     208     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)
#     140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:766, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     763 try:
#     764     # Request a connection from the queue.
#     765     timeout_obj = self._get_timeout(timeout)
# --> 766     conn = self._get_conn(timeout=pool_timeout)
#     768     conn.timeout = timeout_obj.connect_timeout  # type: ignore[assignment]
#     770     # Is this a closed/new connection that requires CONNECT tunnelling?
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:288, in HTTPConnectionPool._get_conn(self, timeout)
#     285     pass  # Oh well, we'll create a new connection then
#     287 # If this is a persistent connection, check if it got disconnected
# --> 288 if conn and is_connection_dropped(conn):
#     289     log.debug("Resetting dropped connection: %s", self.host)
#     290     conn.close()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\util\connection.py:20, in is_connection_dropped(conn)
#      15 def is_connection_dropped(conn: BaseHTTPConnection) -> bool:  # Platform-specific
#      16     """
#      17     Returns True if the connection is dropped and should be closed.
#      18     :param conn: :class:`urllib3.connection.HTTPConnection` object.
#      19     """
# ---> 20     return not conn.is_connected
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connection.py:349, in HTTPConnection.is_connected(self)
#     347 if self.sock is None:
#     348     return False
# --> 349 return not wait_for_read(self.sock, timeout=0.0)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\util\wait.py:117, in wait_for_read(sock, timeout)
#     113 def wait_for_read(sock: socket.socket, timeout: float | None = None) -> bool:
#     114     """Waits for reading to be available on a given socket.
#     115     Returns True if the socket is readable, or False if the timeout expired.
#     116     """
# --> 117     return wait_for_socket(sock, read=True, timeout=timeout)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\util\wait.py:53, in select_wait_for_socket(sock, read, write, timeout)
#      47 # When doing a non-blocking connect, most systems signal success by
#      48 # marking the socket writable. Windows, though, signals success by marked
#      49 # it as "exceptional". We paper over the difference by checking the write
#      50 # sockets for both conditions. (The stdlib selectors module does the same
#      51 # thing.)
#      52 fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 53 rready, wready, xready = fn(timeout)
#      54 return bool(rready or wready or xready)
#
# KeyboardInterrupt:

# %%
# Check index statistics
stats = index.describe_index_stats()
print(stats)
# Out:
# {'dimension': 768,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 7600}},
#  'total_vector_count': 7600,
#  'vector_type': 'dense'}

# %%
# Example: fetch first 3 vectors
ids_to_fetch = [f"chunk-{i}" for i in range(3)]

fetched = index.fetch(ids=ids_to_fetch)
print(fetched)
# Out:
# FetchResponse(namespace='', vectors={'chunk-1': Vector(id='chunk-1', values=[0.0690192357, -0.0522028357, -0.0558619685, -0.0108925952, 0.00571820186, 0.0129024163, 0.0935651287, 0.00927436724, 0.00907278527, -0.0425153635, 0.0623959862, 0.0183351319, 0.0384162441, 0.0992040858, 0.0649987, -0.0397860706, 0.0496518835, 0.00248506013, -0.0583570376, 0.0524932332, -0.00204072683, 0.0224172343, -0.00616179919, 0.0306997336, 0.0132681383, -0.035977453, 0.0447034128, -0.00200463249, 0.0126982527, -0.0428372547, 0.0303309374, -0.0539201312, -0.0118305786, -0.0378958, 2.17446109e-06, 0.00253964891, -0.0290798191, -0.00328154466, -0.020537002, -0.041252844, 0.063085027, 0.0440394953, -0.00146796741, 0.0590871908, 0.00810413808, -0.0564720519, 0.0383002944, 0.0452551618, -0.0238774922, 0.0251167528, 0.00609636214, -0.00948486291, -0.0408278294, 0.00341522531, -0.0738738105, 0.0588431656, -0.0119770756, 0.000610164891, 0.0543838255, 0.0346503854, 0.0208726507, -0.00741212582, -0.00522405049, 0.0113161197, 0.0653732, 0.0281730853, 0.0557554215, -0.0329365358, 0.0203882027, -0.0186588168, 0.104774468, 0.0208258275, 0.0190566313, 0.0589573607, -0.0643237, -0.00500725303, -0.00396668678, -0.00649595447, -0.0339466594, -0.0341775492, -0.0421261042, 0.0194882881, -0.0237562619, 0.00289766979, 0.018858714, 0.0354340523, 0.00545982178, 0.0362292752, -0.0580219366, -0.0359478332, 0.105781287, -0.0174451731, -0.00503244437, -0.015487005, 0.0275737271, -0.00886328518, -0.0249054637, -0.0254007392, 0.0353022963, 0.0154048894, 0.00254461216, -0.02152914, -0.013570074, 0.0181816071, 0.00867471937, -0.0140308812, -0.0016350447, -0.0868869, -0.00630252436, 0.0318387896, 0.00609092368, -0.00661050156, -0.0400357768, 0.0562598407, -0.0437110178, -0.0370964073, -0.0106771355, 0.0633338168, 0.0544819646, 0.0437722951, 0.00434208894, 0.00388326752, -0.0445963927, -0.00607743394, 0.0117107062, -0.000206347802, -0.0193081331, 0.0194313508, 0.00668083085, -0.0507946312, 0.0259584822, 0.00635182345, -0.00691238232, -0.0115397498, -0.0341415703, 0.0989916772, 0.044668939, 0.0196291972, -0.0623210631, -0.014451894, 0.0392654203, 0.0338193402, -0.0577987172, -0.0494482666, -0.0666050911, 0.0227375962, 0.02075064, 0.00312260445, -0.00506746443, 0.0455470756, -0.0369581021, -0.043231871, -0.090659894, -0.0193564, 0.0611560121, 0.0311673377, 0.0748554543, -0.0130495038, 0.0098013971, 0.0331579968, 0.0356203318, 0.00133652776, 0.00720296474, 0.0172887873, -0.0595257357, -0.0167329311, -0.00499211345, 0.0241599325, -0.0393363088, -0.0225085057, -0.0195407439, 0.000971051049, -0.0133709442, 0.0817596838, 0.0661442429, 0.0362843424, 0.0355138443, 0.0371785, 0.0141168525, 0.075464271, -0.0178502146, -0.0938274637, -0.00145014806, -0.00223115296, -0.033370506, 0.0249100849, -0.0590755828, 0.0391019471, -0.000284833368, 0.0031928441, 0.00666141137, -0.0210145563, 0.00206920295, -0.014283916, 0.00214448222, -0.000160800468, -0.0443958566, -0.000464037206, -0.035874743, 0.0260681938, -0.00346070551, -0.0522846244, -0.00530659035, 0.0791722909, 0.0364476, -0.0320406556, -0.0748978108, -0.00486578932, -0.00118276884, 0.0253689364, -0.00732955663, 0.027401045, -0.0444277301, -0.0160959177, -0.00486690924, -0.00379340048, 0.00442137569, -0.0127094416, -0.060969431, 0.0472692251, -0.0199546, -0.0379334353, -0.00119108078, 0.0104682632, 0.00713321, 0.00301329023, -0.0587798543, 0.0282524098, -0.0416421071, 0.0235541798, -0.0068226927, -0.000456731621, 0.00830032863, 0.0161803234, -0.0221254788, -0.000731411565, 0.0930393636, 0.0691300109, -0.012932363, -0.0304767061, -0.0250006635, 0.0336248837, 0.0181374941, 0.0105779506, 0.0809536725, -0.0543613322, 0.0076688379, 0.0625949055, -0.00140740513, 0.00585114863, 0.0236035883, -0.0225788467, 0.00331134466, 0.041012086, 0.0269238502, -0.0337735, -0.0406829454, 0.0448164493, 0.026989691, 0.0231617037, 0.0231851861, -0.0526525453, 0.0119004352, 0.0187311675, 0.0159178935, -0.0459622703, 0.0386835635, -0.0578390211, -0.0289697889, -0.004895 ...

# %%
# Initialize the embedding function
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
# Connect LangChain to the Pinecone index
vector_store = LangchainPinecone(
    index_name="chatbot-index",
    embedding_function=embeddings,
    pinecone_api_key=PINECONE_API_KEY
)

retriever = vector_store.as_retriever(search_kwargs={"k": 3})  # k: number of docs returned
